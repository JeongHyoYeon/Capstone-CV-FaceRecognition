        "id": 80,
        "url": "https://capstone-aftertrip-test.s3.ap-northeast-2.amazonaws.com/2ac71320-05b6-476e-b679-110860baf820"
    },
    {
        "id": 81,
        "url": "https://capstone-aftertrip-test.s3.ap-northeast-2.amazonaws.com/5d7beaf6-28b5-40a4-a0cd-dda6eb1ef9ad"
    },
    {
        "id": 82,
        "url": "https://capstone-aftertrip-test.s3.ap-northeast-2.amazonaws.com/b7893629-7096-436b-9d6d-b4e384f0cf3c"
    },
    {
        "id": 83,
        "url": "https://capstone-aftertrip-test.s3.ap-northeast-2.amazonaws.com/2e808b82-cdd2-487e-a10b-8e9ea5495323"
    },
    {
        "id": 84,
        "url": "https://capstone-aftertrip-test.s3.ap-northeast-2.amazonaws.com/c1631553-a46c-4242-9492-ec644a7d95ad"
    },
    {
        "id": 85,
        "url": "https://capstone-aftertrip-test.s3.ap-northeast-2.amazonaws.com/f3c25193-fa1f-4e5a-8077-903b4e0a6b6a"
    }
]

# %%
#----------------------------------------------------------
#                          drive mount 
#----------------------------------------------------------
from google.colab import drive
drive.mount('/content/drive/')

#%cd /content/drive/MyDrive/
#!git clone https://github.com/vinotharjun/FaceGrouping.git

#%cd /content/drive/MyDrive/
#!git clone https://github.com/JeongHyoYeon/Capstone-CV-FaceRecognition.git
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#----------------------------------------------------------
#                          install 
#----------------------------------------------------------
base_folder = '/content/drive/MyDrive/Capstone_Face_Test'
# %cd {base_folder}

# !pip install mtcnn
# !pip install -r requirements.txt #embedding & tsne 위한 설치
# Out:
# /content/drive/MyDrive/Capstone_Face_Test
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached matplotlib-3.3.0.tar.gz (38.8 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached numpy-1.19.0.zip (7.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ERROR: Could not find a version that satisfies the requirement opencv-python==4.3.0.36 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.14.51, 3.4.14.53, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.2.52, 4.5.2.54, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66, 4.7.0.68, 4.7.0.72)
# ...

# %%
from face_recognition.face_recognition import face_recognition

groups, images = face_recognition(images)
# Out:
# Step1. face detect
#
# ...
# 2/2 [==============================] - 0s 44ms/step
# crop_path =  ./crop_images/crop/0_1.jpg
# crop_path =  ./crop_images/crop/0_2.jpg
# crop_path =  ./crop_images/crop/0_3.jpg
# crop_path =  ./crop_images/crop/0_4.jpg
# crop_path =  ./crop_images/crop/0_5.jpg
# crop_path =  ./crop_images/crop/0_6.jpg
# 1/1 [==============================] - 0s 323ms/step
# ...

# %% [markdown]
# # 테스트 코드

# %%
# grouping 잘됐나 테스트 1 (crop 이미지만 보기)
from google.colab.patches import cv2_imshow
import cv2

for i in range(len(groups)):
  print("======================================================")
  print("====================== group", i, "=======================")
  for j in range(len(groups[i]["face_list"])):
    print("face idx = ", groups[i]["face2_idx_list"][j]) #face idx
    print("cosine = ", groups[i]["cosine_similarity_list"][j]) #cosine distance
    #cv2_imshow(groups[i]["face_list"][j]) #face

    crop_path = groups[i]["crop_path_list"][j]
    print("crop_path = ", crop_path)
    cv2_imshow(cv2.imread(crop_path))
# Out:
# ...
# ====================== group 0 =======================
# face idx =  0
# cosine =  -1
# crop_path =  ./crop_images/crop/0_1.jpg
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7F67FDABBFD0>
# ...
# ====================== group 1 =======================
# face idx =  1
# cosine =  -1
# crop_path =  ./crop_images/crop/0_2.jpg
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7F67FDA1C4F0>
# ...
# ====================== group 2 =======================
# face idx =  2
# cosine =  -1
# crop_path =  ./crop_images/crop/0_3.jpg
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7F67FDABB940>
# ...
# ====================== group 3 =======================
# face idx =  3
# cosine =  -1
# crop_path =  ./crop_images/crop/0_4.jpg
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7F694D996460>
# ...
# ====================== group 4 =======================
# face idx =  4
# cosine =  -1
# crop_path =  ./crop_images/crop/0_5.jpg
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7F67FDABBDF0>
# face idx =  9
# ...

# %%
#  최종값 잘 들어갔나 확인 (images에 group_idx list가 최종값)
for _, image in enumerate(images):
  print("image idx = ", image["id"])
  for _, group_idx in enumerate(image["group_idx"]):
    print(group_idx)
# Out:
# image idx =  65
# 4
# 5
# -1
# image idx =  66
# 4
# 8
# -1
# image idx =  67
# 13
# 10
# -1
# image idx =  68
# 10
# 8
# 4
# -1
# image idx =  69
# 4
# image idx =  70
# 4
# image idx =  71
# 5
# image idx =  72
# -1
# image idx =  73
# -1
# image idx =  74
# -1
# image idx =  75
# 8
# 4
# -1
# image idx =  76
# 8
# -1
# image idx =  77
# 10
# -1
# image idx =  78
# 13
# image idx =  79
# 5
# image idx =  80
# -1
# image idx =  81
# -1
# image idx =  82
# -2
# image idx =  83
# -2
# image idx =  84
# -1
# image idx =  85
# -2
